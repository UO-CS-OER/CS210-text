# %% [markdown]
# # Interlude: Careers in Computing
#
# by [Audra McNamee](https://audmcname.com/) with Michal Young
# [PDF version](img/cs-careers.pdf)
#
# ![Page 1](img/cs-careers-1.jpg)
#
# ![Page 2](img/cs-careers-2.jpg)
#
# ![Page 3](img/cs-careers-3.jpg)
#
# ![Page 4](img/cs-careers-4.jpg)
#
# ![Page 5](img/cs-careers-5.jpg)
